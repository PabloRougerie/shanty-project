# %%
import sys
from pathlib import Path
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root))

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from lightgbm import LGBMRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import GroupShuffleSplit
from sklearn.linear_model import Ridge
from sklearn.preprocessing import RobustScaler
from sklearn.pipeline import Pipeline

from ml_logic.data_preprocessing import clean_data, resample_pings
from ml_logic.model_evaluation import evaluate_horizon
from ml_logic.feature_engineering import create_time_series_features

import warnings
warnings.filterwarnings('ignore', category=RuntimeWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# %% [markdown]
# # Feature Engineering Analysis
#
# ## Objective
#
# This notebook tests the impact of different feature engineering strategies on model performance:
# 1. **Rolling features**: Sliding window statistics (mean, std) on SOG and COG
# 2. **Advanced features**: Derived features (geometric ratios, meandering index, rate of change)
#
# **Hypothesis**: These additional features should capture non-linear patterns that simple lag features cannot.

# %%
## 1. Data Loading and Preparation
df = pd.read_parquet("../data/processed/ais_filtered.parquet")
df = clean_data(df) #remove missing values and clean
df = resample_pings(df, interval='5min') #uniformize pings

# %% [markdown]
# ## 3. Test effect of rolling features

# %% [markdown]
# The rolling features are rolling average and std on SOG and COG

# %%
#create model (same as in notebook 3)
estimators = {
    "Ridge_scaled": Pipeline([
        ('scaler', RobustScaler()),
        ('model', Ridge(alpha=1.0))
    ]),
    "LightGBM": LGBMRegressor(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=273,
        n_jobs=-1,
        verbose=-1
    )
}

results_no_rolling = []
results_with_rolling = []

horizons = [60, 120, 180, 240, 360, 480, 540,  720,  1080, 1440, 2880]
for horizon in horizons:
    print(f"\nHorizon: {horizon} min")

    # Sans rolling
    print("Without rolling features:")
    nb_pings, nb_vessels, mae_scores = evaluate_horizon(
        df, horizon, estimators,
        test_size=0.2,
        random_state=273,
        rolling=False
    )
    results_no_rolling.append({
        'horizon_min': horizon,
        'nb_pings': nb_pings,
        'nb_vessels': nb_vessels,
        **mae_scores
    })

    # Avec rolling
    print("With rolling features:")
    nb_pings, nb_vessels, mae_scores = evaluate_horizon(
        df, horizon, estimators,
        test_size=0.2,
        random_state=273,
        rolling=True
    )
    results_with_rolling.append({
        'horizon_min': horizon,
        'nb_pings': nb_pings,
        'nb_vessels': nb_vessels,
        **mae_scores
    })


df_no_rolling = pd.DataFrame(results_no_rolling)
df_with_rolling = pd.DataFrame(results_with_rolling)

print("\n=== WITHOUT ROLLING ===")
print(df_no_rolling)
print("\n=== WITH ROLLING ===")
print(df_with_rolling)

# %% [markdown]
# Conclusion: no effect of rolling features on prediction

# %% [markdown]
# ## Impact of advanced features

# %% [markdown]
# The advanced features are derived featuers like the boat aspect ratio, the boat meandering index, the acceleration.

# %%
df = pd.read_parquet("../data/processed/ais_filtered.parquet")
df = clean_data(df) #remove missing values and clean
df = resample_pings(df, interval='5min') #uniformize pings

#create model (same as in notebook 3)
estimators = {
    "Ridge_scaled": Pipeline([
        ('scaler', RobustScaler()),
        ('model', Ridge(alpha=1.0))
    ]),
    "LightGBM": LGBMRegressor(
        n_estimators=200,
        max_depth=6,
        learning_rate=0.1,
        subsample=0.8,
        colsample_bytree=0.8,
        random_state=273,
        n_jobs=-1,
        verbose=-1
    )
}

results_no_advanced = []
results_with_advanced = []

horizons = [60, 120, 180, 300, 420, 540,  660, 840, 1080, 1440,2160]
for horizon in horizons:
    print(f"\nHorizon: {horizon} min")

    # Without advanced features
    print("Without advanced features:")
    nb_pings, nb_vessels, mae_scores = evaluate_horizon(
        df, horizon, estimators,
        test_size=0.2,
        random_state=273,
        rolling=False,
        advanced_features= False
    )
    results_no_advanced.append({
        'horizon_min': horizon,
        'nb_pings': nb_pings,
        'nb_vessels': nb_vessels,
        **mae_scores
    })

    # With advanced features
    print("With advanced features:")
    nb_pings, nb_vessels, mae_scores = evaluate_horizon(
        df, horizon, estimators,
        test_size=0.2,
        random_state=273,
        rolling=False,
        advanced_features= True
    )
    results_with_advanced.append({
        'horizon_min': horizon,
        'nb_pings': nb_pings,
        'nb_vessels': nb_vessels,
        **mae_scores
    })

# Convertir en DataFrames
df_no_advanced = pd.DataFrame(results_no_advanced)
df_with_advanced = pd.DataFrame(results_with_advanced)

# Comparer
print("\n=== WITHOUT ADVANCED FEATURES ===")
print(df_no_advanced)
print("\n=== WITH ADVANCED FEATURES ===")
print(df_with_advanced)
# Out:
# <>:28: SyntaxWarning: invalid escape sequence '\H'
# <>:28: SyntaxWarning: invalid escape sequence '\H'
# /var/folders/dk/v6_xfc950bb08vyf1lm9v0x00000gn/T/ipykernel_99834/4230388349.py:28: SyntaxWarning: invalid escape sequence '\H'
#   print(f"\Horizon: {horizon} min")
# \Horizon: 60 min
# Without advanced features:
# Target prediction horizon: 60 min. Number of steps: 12
# Defining lag windows of 10min, 30min, 60min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 60 min. Number of steps: 12
# Defining lag windows of 10min, 30min, 60min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 120 min
# Without advanced features:
# Target prediction horizon: 120 min. Number of steps: 24
# Defining lag windows of 20min, 60min, 120min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 120 min. Number of steps: 24
# Defining lag windows of 20min, 60min, 120min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 180 min
# Without advanced features:
# Target prediction horizon: 180 min. Number of steps: 36
# Defining lag windows of 30min, 90min, 180min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 180 min. Number of steps: 36
# Defining lag windows of 30min, 90min, 180min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 300 min
# Without advanced features:
# Target prediction horizon: 300 min. Number of steps: 60
# Defining lag windows of 50min, 150min, 300min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 300 min. Number of steps: 60
# Defining lag windows of 50min, 150min, 300min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 420 min
# Without advanced features:
# Target prediction horizon: 420 min. Number of steps: 84
# Defining lag windows of 70min, 210min, 420min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 420 min. Number of steps: 84
# Defining lag windows of 70min, 210min, 420min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 540 min
# Without advanced features:
# Target prediction horizon: 540 min. Number of steps: 108
# Defining lag windows of 90min, 270min, 540min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 540 min. Number of steps: 108
# Defining lag windows of 90min, 270min, 540min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 660 min
# Without advanced features:
# Target prediction horizon: 660 min. Number of steps: 132
# Defining lag windows of 110min, 330min, 660min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 660 min. Number of steps: 132
# Defining lag windows of 110min, 330min, 660min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 840 min
# Without advanced features:
# Target prediction horizon: 840 min. Number of steps: 168
# Defining lag windows of 140min, 420min, 840min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 840 min. Number of steps: 168
# Defining lag windows of 140min, 420min, 840min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 1080 min
# Without advanced features:
# Target prediction horizon: 1080 min. Number of steps: 216
# Defining lag windows of 180min, 540min, 1080min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 1080 min. Number of steps: 216
# Defining lag windows of 180min, 540min, 1080min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 1440 min
# Without advanced features:
# Target prediction horizon: 1440 min. Number of steps: 288
# Defining lag windows of 240min, 720min, 1440min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 1440 min. Number of steps: 288
# Defining lag windows of 240min, 720min, 1440min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# \Horizon: 2160 min
# Without advanced features:
# Target prediction horizon: 2160 min. Number of steps: 432
# Defining lag windows of 360min, 1080min, 2160min
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
# With advanced features:
# Target prediction horizon: 2160 min. Number of steps: 432
# Defining lag windows of 360min, 1080min, 2160min
# Adding advanced engineered features
# Testing model Ridge_scaled
# fitting...
# predicting...
# Testing model LightGBM
# fitting...
# predicting...
#
# === WITHOUT ADVANCED FEATURES ===
#     horizon_min  nb_pings  nb_vessels    Baseline  Ridge_scaled   LightGBM
# 0            60   1087194         968    1.753313      2.800644   2.990115
# 1           120   1064034         961    4.196586      5.333290   4.820111
# 2           180   1041000         957    7.010242      7.981123   6.552487
# 3           300    995513         937   13.287778     13.673977  11.820383
# 4           420    950907         923   18.547231     17.533188  14.999086
# 5           540    907172         897   24.387719     21.833698  21.694971
# 6           660    864508         876   32.189836     28.371991  29.498565
# 7           840    802731         845   43.250962     33.707213  32.855011
# 8          1080    723384         811   54.969506     42.097000  43.196401
# 9          1440    610350         748   61.083400     46.700319  47.274656
# 10         2160    412783         620  107.572315     67.297340  80.043225
#
# === WITH ADVANCED FEATURES ===
#     horizon_min  nb_pings  nb_vessels    Baseline  Ridge_scaled   LightGBM
# 0            60   1087194         968    1.753313      2.830309   2.933523
# 1           120   1064034         961    4.196586      5.383112   4.962098
# 2           180   1041000         957    7.010242      7.985608   6.710120
# 3           300    995513         937   13.287778     13.685774  12.140840
# 4           420    950907         923   18.547231     17.552683  16.064845
# 5           540    907172         897   24.387719     22.017490  23.007505
# 6           660    864508         876   32.189836     28.764511  30.517179
# 7           840    802731         845   43.250962     33.644963  34.706480
# 8          1080    723384         811   54.969506     42.155492  45.078753
# 9          1440    610350         748   61.083400     47.046612  48.516597
# 10         2160    412783         620  107.572315     67.645962  81.729899

# %% [markdown]
# Conclusion: no effect of advanced features
