# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import tensorflow as tf
#       2 print(tf.config.list_physical_devices('GPU'))
#
# File ~/.pyenv/versions/3.12.9/envs/vessel_tracker/lib/python3.12/site-packages/tensorflow/__init__.py:438
#     436 _plugin_dir = _os.path.join(_s, "tensorflow-plugins")
#     437 if _os.path.exists(_plugin_dir):
# --> 438   _ll.load_library(_plugin_dir)
#     439   # Load Pluggable Device Library
#     440   _ll.load_pluggable_device_library(_plugin_dir)
#
# File ~/.pyenv/versions/3.12.9/envs/vessel_tracker/lib/python3.12/site-packages/tensorflow/python/framework/load_library.py:151, in load_library(library_location)
#     148     kernel_libraries = [library_location]
#     150   for lib in kernel_libraries:
# --> 151     py_tf.TF_LoadLibrary(lib)
#     153 else:
#     154   raise OSError(
# ...
